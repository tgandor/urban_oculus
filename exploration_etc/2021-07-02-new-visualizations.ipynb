# %%
from evaldets.visualization import *
from evaldets.results import DetectionResults

# %%
dets = DetectionResults('~/reval_50/R101/evaluator_dump_R101_075/', iou_thresh=0.2)

# %%
len(dets)
# Out:
# 22778

# %%
dets[1]
# Out:
# {'image_id': 139,
#  'score': 0.837469756603241,
#  'iou': 0.8847278540544438,
#  'gt_id': 104368,
#  'category': 'chair',
#  'x': 294.61883544921875,
#  'y': 218.6697235107422,
#  'w': 56.51171875,
#  'h': 100.61647033691406}

# %%
DSI.gt[104368]
# Out:
# {'area': 1833.7840000000017,
#  'iscrowd': 0,
#  'image_id': 139,
#  'bbox': [290.69, 218.0, 61.83, 98.48],
#  'id': 104368,
#  'category': 'chair'}

# %%
show_detection(dets[1205], scale=2.0, v=1, q=75)
# Out:
# image_id = 27768
# img=27768: car 60.9 J=49.5 GT#132502
# <PIL.Image.Image image mode=RGB size=1224x1224 at 0x7F98E34EB790>

# %%
d = 1467

# %%
d += 1
print(d)
show_detection(dets[d], crop=True, v=True, crop_margin=10, q=75, scale=3)
# Out:
# 1468
# image_id = 33638
# img=33638: oven 60.5 J=32.8 GT#2196139
# <PIL.Image.Image image mode=RGB size=897x862 at 0x7F98E3DF9B80>

# %%
show_detections(dets[:10], scale=1.5, v=1, q=75)
# Out:
# image_id = 139
# img=139: tv 91.2 J=96.2 GT#34646
# img=139: chair 83.7 J=88.5 GT#104368
# img=139: person 81.0 J=90.3 GT#230831
# img=139: vase 77.1 (FP) (no GT)
# img=139: tv 72.1 J=88.4 GT#35802
# img=139: potted plant 71.4 J=36.5 GT#26547
# img=139: chair 68.8 J=88.2 GT#103487
# img=139: chair 67.8 J=87.5 GT#105328
# img=139: clock 65.4 J=88.0 GT#1666628
# img=139: bottle 64.0 (FP) (no GT)
# <PIL.Image.Image image mode=RGB size=960x639 at 0x7F98E37B9820>

# %%
len(DSI.gt)
# Out:
# 36781

# %%
show_image_objects(33638+0*27768, show_ids=True)
# Out:
# <PIL.Image.Image image mode=RGB size=850x1280 at 0x7F98DF84CDC0>

# %%
show_detections(dets.detections_by_image_id(33638))
# Out:
# image_id = 33638
# <PIL.Image.Image image mode=RGB size=425x640 at 0x7F98DF9224C0>
